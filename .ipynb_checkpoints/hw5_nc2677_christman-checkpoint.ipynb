# %% [markdown]
# # COMS-E6998-010: Homework 4 {-}
# __Name:__ Nicholas Christman (n2677)
# __Due:__ Nov. 22, 2002

# %%
from __future__ import print_function, division

import sys
import time
import os
import shutil
import random
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import json
from pprint import pprint
# from IPython.display import display,SVG,HTML,IFrame,Image
import IPython.display as ipd
from PIL import Image

import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torchvision
from torchvision import datasets, models, transforms

from scipy.optimize import curve_fit
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# set global seed
seed = 6998
torch.manual_seed(seed)
random.seed(seed)

# %%
# use a GPU if there is one available
cuda_availability = torch.cuda.is_available()
if cuda_availability:
    device = torch.device('cuda:{}'.format(torch.cuda.current_device()))
else:
    device = 'cpu'
print('\n*************************')
print('GPU Available: {}'.format(cuda_availability))
print('Current Device: {}'.format(device))
print('*************************\n')
# display the GPU info
if cuda_availability:
    # !nvidia-smi
# Out:
# *************************
# GPU Available: True
# Current Device: cuda:0
# *************************
#
# Sun Dec  6 07:11:41 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.87.01    Driver Version: 418.87.01    CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    29W /  70W |     10MiB / 15079MiB |      5%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Problem 1 - SSD, ONNX model, Visualization, Inferencing (35) {-}
# Following the github repo and ONNX tutorials (links provided below), start with a pretrained Pytorch SSD model and retrain it for your target categories, convert the Pytorch model to ONNX, and then deploy it on ONNX runtime server for inferencing.
#
# For part 1, 2, and 3, refer to the steps in the github repo. For part 4 refer to ONNX tutorial on visualizing and for 5 and 6 refer to ONNX tutorial on inferencing.
#
# _References:_
# * Github repo. Shot MultiBox Detector Implementation in Pytorch.
# Available at https://github.com/qfgaohao/pytorch-ssd
# * ONNX tutorial. Visualizing an ONNX Model.
# Available at https://github.com/onnx/tutorials/blob/master/tutorials/VisualizingAModel.md
# * ONNX tutorial. Inferencing SSD ONNX model using ONNX Runtime Server.
# Available at https://github.com/onnx/tutorials/blob/master/tutorials/OnnxRuntimeServerSSDModel.ipynb
# * Google. Open Images Dataset V5 + Extensions.
# Available at https://storage.googleapis.com/openimages/web/index.html
# * The PASCAL Visual Object Classes Challenge 2007.
# Available at http://host.robots.ox.ac.uk/pascal/VOC/voc2007/

# %% [markdown]
# ### 1.1  Pretrained MobilenetV1 SSD tested locally with  Pascal VOC 2007 dataset (show the test accuracy for the 20 classes) {-}

# %%
# getting the trainval data
# ! wget -P data/trainval http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# ! tar -xf data/trainval/VOCtrainval_06-Nov-2007.tar -C data/trainval
# Out:
# --2020-11-30 06:22:17--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘data/trainval/VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  16.7MB/s    in 28s
#
# 2020-11-30 06:22:45 (15.7 MB/s) - ‘data/trainval/VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]

# %%
# getting the  test data 
# ! wget -P data/test http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# ! tar -xf data/test/VOCtest_06-Nov-2007.tar -C data/test
# Out:
# --2020-11-30 06:22:54--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘data/test/VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  17.2MB/s    in 27s
#
# 2020-11-30 06:23:22 (15.8 MB/s) - ‘data/test/VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
# getting the model/labels
! wget -P models https://storage.googleapis.com/models-hao/mobilenet-v1-ssd-mp-0_675.pth
! wget -P models https://storage.googleapis.com/models-hao/voc-model-labels.txt
# Out:
# --2020-12-05 02:47:15--  https://storage.googleapis.com/models-hao/mobilenet-v1-ssd-mp-0_675.pth
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 74.125.142.128, 74.125.195.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37995286 (36M) [application/octet-stream]
# Saving to: ‘models/mobilenet-v1-ssd-mp-0_675.pth’
#
# mobilenet-v1-ssd-mp 100%[===================>]  36.23M   111MB/s    in 0.3s
#
# 2020-12-05 02:47:15 (111 MB/s) - ‘models/mobilenet-v1-ssd-mp-0_675.pth’ saved [37995286/37995286]
#
# --2020-12-05 02:47:15--  https://storage.googleapis.com/models-hao/voc-model-labels.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.197.128, 74.125.20.128, 74.125.142.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.197.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145 [text/plain]
# Saving to: ‘models/voc-model-labels.txt’
#
# voc-model-labels.tx 100%[===================>]     145  --.-KB/s    in 0s
#
# 2020-12-05 02:47:16 (222 MB/s) - ‘models/voc-model-labels.txt’ saved [145/145]

# %%
# test model with Pascal VOC 2007 dataset
# ! python pytorch-ssd/eval_ssd.py --net mb1-ssd \
# --dataset data/test/VOCdevkit/VOC2007/ \
# --trained_model models/mobilenet-v1-ssd-mp-0_675.pth \
# --label_file models/voc-model-labels.txt
# --trained_model pytorch-ssd/models/mobilenet-v1-ssd-mp-0_675.pth \
# --label_file pytorch-ssd/models/voc-model-labels.txt

# %% [markdown]
# _Note: this is a snippet from the actual output._
#
# ```
# pytorch-ssd/eval_ssd.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
# It took 0.0654754638671875 seconds to load the model.
# process image 0
# Load Image: 0.025498 seconds.
# Inference time:  0.8003177642822266
# Prediction: 0.859447 seconds.
# process image 1
# Load Image: 0.004779 seconds.
# Inference time:  0.007477521896362305
# Prediction: 0.059341 seconds.
# ...
# process image 4950
# Load Image: 0.004848 seconds.
# Inference time:  0.005615711212158203
# Prediction: 0.037452 seconds.
# process image 4951
# Load Image: 0.005250 seconds.
# Inference time:  0.005333900451660156
# Prediction: 0.039187 seconds.
#
#
# Average Precision Per-class:
# aeroplane: 0.6742489426027927
# bicycle: 0.7913672875238116
# bird: 0.612096015101108
# boat: 0.5616402776942253
# bottle: 0.3471256662634949
# bus: 0.7742298893362103
# car: 0.7284171192326804
# cat: 0.8360675520354323
# chair: 0.5142295855384792
# cow: 0.6244090341627014
# diningtable: 0.7060035669312754
# dog: 0.7849252606216821
# horse: 0.8202146617282785
# motorbike: 0.793578272243471
# person: 0.7042670984734087
# pottedplant: 0.40257147509774405
# sheep: 0.6071252282334352
# sofa: 0.7549120254763918
# train: 0.8270992920206008
# tvmonitor: 0.6459903029666852
#
# Average Precision Across All Classes:0.6755259276641954
# ```

# %% [markdown]
# #### Answer:
# The test accuracy for all 20 classes are shown above, with an average precision of 67.6% across all classes.

# %% [markdown]
# ### 1.2  Select two related categories from Google Open Images and finetune the pretrained SSD model. {-}
# * Use _open_images_downloader.py_ script.
# * Use the same parameters that are used in the tutorial.

# %%
# select the target categories
cat1 = 'Beer'#'Human eye'#'Beer'#'Pomegranate'#'Traffic light' #'Tree'
cat2 = 'Bottle'#'Human mouth'#'Bottle'#'Apple'#'Traffic sign' #'Christmas Tree'
class_names = f"\"{cat1}, {cat2}\""
root = 'data/open_images'
# image directories (in case needed)
train_images = f'{root}/training'
val_images = f'{root}/validation'
test_images = f'{root}/test' #used for drawing box

class_names
# Out:
# '"Beer, Bottle"'

# %%
# getting the Google Open Image data
# ! python pytorch-ssd/open_images_downloader.py --root $root \
#                                                --class_names $class_names \
#                                                --num_workers 20

# %% [markdown]
# ```
# 2020-12-06 07:13:34,486 - root - Download https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv.
# 2020-12-06 07:13:34,572 - root - Download https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv.
# 2020-12-06 07:13:55,913 - root - Read annotation file data/open_images/train-annotations-bbox.csv
# 2020-12-06 07:14:09,783 - root - train bounding boxes size: 49753
# 2020-12-06 07:14:09,783 - root - Approximate Image Stats:
# 2020-12-06 07:14:09,799 - root - Bottle: 11456/16117 = 0.71.
# 2020-12-06 07:14:09,799 - root - Beer: 4661/16117 = 0.29.
# 2020-12-06 07:14:09,799 - root - Label distribution:
# 2020-12-06 07:14:09,804 - root - Bottle: 40188/49753 = 0.81.
# 2020-12-06 07:14:09,804 - root - Beer: 9565/49753 = 0.19.
# 2020-12-06 07:14:09,804 - root - Shuffle dataset.
# 2020-12-06 07:14:09,804 - root - Save train data to data/open_images/sub-train-annotations-bbox.csv.
# 2020-12-06 07:14:10,192 - root - Download https://storage.googleapis.com/openimages/2018_04/validation/validation-annotations-bbox.csv.
# 2020-12-06 07:14:10,473 - root - Read annotation file data/open_images/validation-annotations-bbox.csv
# 2020-12-06 07:14:10,704 - root - validation bounding boxes size: 458
# 2020-12-06 07:14:10,704 - root - Approximate Image Stats:
# 2020-12-06 07:14:10,707 - root - Bottle: 177/260 = 0.68.
# 2020-12-06 07:14:10,707 - root - Beer: 83/260 = 0.32.
# 2020-12-06 07:14:10,707 - root - Label distribution:
# 2020-12-06 07:14:10,707 - root - Bottle: 340/458 = 0.74.
# 2020-12-06 07:14:10,708 - root - Beer: 118/458 = 0.26.
# 2020-12-06 07:14:10,708 - root - Shuffle dataset.
# 2020-12-06 07:14:10,708 - root - Save validation data to data/open_images/sub-validation-annotations-bbox.csv.
# 2020-12-06 07:14:10,712 - root - Download https://storage.googleapis.com/openimages/2018_04/test/test-annotations-bbox.csv.
# 2020-12-06 07:14:11,620 - root - Read annotation file data/open_images/test-annotations-bbox.csv
# 2020-12-06 07:14:12,263 - root - test bounding boxes size: 1311
# 2020-12-06 07:14:12,263 - root - Approximate Image Stats:
# 2020-12-06 07:14:12,266 - root - Bottle: 533/741 = 0.72.
# 2020-12-06 07:14:12,266 - root - Beer: 208/741 = 0.28.
# 2020-12-06 07:14:12,266 - root - Label distribution:
# 2020-12-06 07:14:12,267 - root - Bottle: 979/1311 = 0.75.
# 2020-12-06 07:14:12,267 - root - Beer: 332/1311 = 0.25.
# 2020-12-06 07:14:12,267 - root - Shuffle dataset.
# 2020-12-06 07:14:12,267 - root - Save test data to data/open_images/sub-test-annotations-bbox.csv.
# 2020-12-06 07:14:12,278 - root - Start downloading 15074 images.
# 2020-12-06 07:14:14,487 - root - Downloaded 100 images.
#
# ...
#
# 2020-12-06 07:17:10,716 - root - Downloaded 15000 images.
# 2020-12-06 07:17:13,589 - root - Task Done.
# ```

# %% [markdown]
# ### Accuracy before finetuning
# The accuracy before finetuning was captured by training with the pretrained model for 1 epoch so to produce the correct output dimensions, and and then evaluate the new (1 epoch) model (this gets us close to what we would see from the original model). Refer to Piazza @349.
#
# #### Answer:
# As can be seen below (before the finetuning portion), the average precision for the 'Traffic light' class before finetuning was 18.2%  and, likewise, the 'Traffic sign' class was 30.8%. Overall, the average precision for all a classes was 24.5%.

# %%
# NOTE: I had to run this from the terminal on this GCP... it was not showing console output
#       correctly when ran in the Jupyter cell
# ! python pytorch-ssd/train_ssd.py --dataset_type open_images \
#                       --datasets data/open_images \
#                       --net mb1-ssd \
#                       --pretrained_ssd models/mobilenet-v1-ssd-mp-0_675.pth \
#                       --use_cuda True \
#                       --scheduler cosine \
#                       --lr 0.01 \
#                       --t_max 100 \
#                       --validation_epochs 5 \
#                       --num_epochs 1 \
#                       --base_net_lr 0.001 \
#                       --batch_size 16

# %% [markdown]
# _Note: this is a snippet from the terminal console output..._
# ```
# (base) jupyter@pytorch-tesla-notebook-instance:~/comse6998-hw5$  python pytorch-ssd/train_ssd.py --dataset_type open_images --datasets data/open_images --net mb1-ssd --pretrained_ssd models/mobilenet-v1-ssd-mp-0_675.pth --use_cuda True --scheduler cosine --lr 0.01 --t_max 100 --validation_epochs 5 --num_epochs 1 --base_net_lr 0.001 --batch_size 162020-12-06 07:18:42,905 - root - INFO - Use Cuda.2020-12-06 07:18:42,905 - root - INFO - Namespace(balance_data=False, base_net=None, base_net_lr=0.001, batch_size=16, checkpoint_folder='models/', dataset_type='open_images', datasets=['data/open_images'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, last_epoch=None, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb1-ssd', num_epochs=1, num_workers=4, pretrained_ssd='models/mobilenet-v1-ssd-mp-0_675.pth', resume=None, scheduler='cosine', t_max=100.0, use_cuda=True, validation_dataset=None, validation_epochs=5, weight_decay=0.0005)
# 2020-12-06 07:18:42,933 - root - INFO - Prepare training datasets.
# 2020-12-06 07:18:51,733 - root - INFO - Dataset Summary:Number of Images: 14147
# Minimum Number of Images for a Class: -1
# Label Distribution:
#         Beer: 9565
#         Bottle: 40188
# 2020-12-06 07:18:51,757 - root - INFO - Stored labels into file models/open-images-model-labels.txt.
# 2020-12-06 07:18:51,757 - root - INFO - Train dataset size: 14147
# 2020-12-06 07:18:51,757 - root - INFO - Prepare Validation datasets.
# 2020-12-06 07:18:52,178 - root - INFO - Dataset Summary:Number of Images: 685
# Minimum Number of Images for a Class: -1
# Label Distribution:
#         Beer: 332
#         Bottle: 979
# 2020-12-06 07:18:52,179 - root - INFO - validation dataset size: 685
# 2020-12-06 07:18:52,180 - root - INFO - Build network.
# 2020-12-06 07:18:52,259 - root - INFO - Init from pretrained ssd models/mobilenet-v1-ssd-mp-0_675.pth
# 2020-12-06 07:18:52,760 - root - INFO - Took 0.50 seconds to load the model.
# 2020-12-06 07:18:57,620 - root - INFO - Learning rate: 0.01, Base net learning rate: 0.001, Extra Layers learning rate: 0.01.
# 2020-12-06 07:18:57,620 - root - INFO - Uses CosineAnnealingLR scheduler.
# 2020-12-06 07:18:57,620 - root - INFO - Start training from epoch 0.
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /opt/conda/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 2020-12-06 07:19:57,922 - root - INFO - Epoch: 0, Step: 100, Average Loss: 5.8860, Average Regression Loss 2.6043, Average Classification Loss: 3.2817
# 2020-12-06 07:20:55,799 - root - INFO - Epoch: 0, Step: 200, Average Loss: 4.6481, Average Regression Loss 1.8541, Average Classification Loss: 2.7940
# 2020-12-06 07:21:53,081 - root - INFO - Epoch: 0, Step: 300, Average Loss: 4.4677, Average Regression Loss 1.8308, Average Classification Loss: 2.6370
# 2020-12-06 07:22:49,993 - root - INFO - Epoch: 0, Step: 400, Average Loss: 4.2892, Average Regression Loss 1.6995, Average Classification Loss: 2.5897
# 2020-12-06 07:23:47,800 - root - INFO - Epoch: 0, Step: 500, Average Loss: 4.1167, Average Regression Loss 1.5822, Average Classification Loss: 2.5346
# 2020-12-06 07:24:44,213 - root - INFO - Epoch: 0, Step: 600, Average Loss: 3.9882, Average Regression Loss 1.4821, Average Classification Loss: 2.5061
# 2020-12-06 07:25:39,460 - root - INFO - Epoch: 0, Step: 700, Average Loss: 3.9987, Average Regression Loss 1.5135, Average Classification Loss: 2.4852
# 2020-12-06 07:26:37,791 - root - INFO - Epoch: 0, Step: 800, Average Loss: 3.9656, Average Regression Loss 1.4661, Average Classification Loss: 2.4995
# 2020-12-06 07:27:27,495 - root - INFO - Trained 0.
# 2020-12-06 07:27:37,987 - root - INFO - Epoch: 0, Validation Loss: 3.3993, Validation Regression Loss 1.0438, Validation Classification Loss: 2.3554
# 2020-12-06 07:27:38,030 - root - INFO - Saved model models/mb1-ssd-Epoch-0-Loss-3.3992867358895236.pth
# ```

# %%
labels_txt = 'models/open-images-model-labels.txt'
model_before = 'models/mb1-ssd-Epoch-0-Loss-3.3992867358895236.pth' # <-- update as needed!
if os.path.isfile(model_before):
    os.rename(model_before,'models/mb1-ssd-before.pth')
    print('\'model_before\' renamed!')
# ! mv $model_before models/mb1-ssd-before.pth 
model_before = 'models/mb1-ssd-before.pth' # <-- renamed for clarity!

# test model with open images dataset and choosen class labels
# UNCOMMENT TO RUN
# print(f'--> {model_before}')
# ! python pytorch-ssd/eval_ssd.py --dataset_type open_images \
#                                 --net mb1-ssd \
#                                 --dataset $root \
#                                 --trained_model $model_before \
#                                 --label_file $labels_txt

# %% [markdown]
# _Note: for brevity, this is a snippet of the actual (full) result._
# ```
# 'model_before' renamed!
# pytorch-ssd/eval_ssd.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
# It took 0.04651021957397461 seconds to load the model.
# process image 0
# Load Image: 0.016437 seconds.
# Inference time:  0.34866952896118164
# Prediction: 0.383213 seconds.
# ...
# process image 684
# Load Image: 0.011649 seconds.
# Inference time:  0.006269216537475586
# Prediction: 0.032790 seconds.
#
#
# Average Precision Per-class:
# Beer: 0.5683927195423516
# Bottle: 0.44861357827252785
#
# Average Precision Across All Classes:0.5085031489074398
# ```

# %% [markdown]
# ### Accuracy after finetuning
# #### Answer:
# As can be seen below (before the finetuning portion), the average precision for the 'Traffic light' class before finetuning was % and, likewise, the 'Traffic sign' class was %. Overall, the average precision for all a classes was %.

# %%
# NOTE: I had to run this from the terminal on this GCP... it was not showing console output
#       correctly when ran in the Jupyter cell
# ! python pytorch-ssd/train_ssd.py --dataset_type open_images \
#                       --datasets data/open_images \
#                       --net mb1-ssd \
#                       --pretrained_ssd models/mobilenet-v1-ssd-mp-0_675.pth \
#                       --use_cuda True \
#                       --scheduler cosine \
#                       --lr 0.01 \
#                       --t_max 100 \
#                       --validation_epochs 5 \
#                       --num_epochs 100 \
#                       --base_net_lr 0.001 \
#                       --batch_size 16

# %% [markdown]
# _Note: this is a snippet from the terminal console output..._
# ```
# (base) jupyter@pytorch-tesla-notebook-instance:~/comse6998-hw5$  python pytorch-ssd/train_ssd.py --dataset_type open_images --datasets data/open_images --net mb1-ssd --pretrained_ssd models/mobilenet-v1-ssd-mp-0_675.pth --use_cuda True --scheduler cosine --lr 0.01 --t_max 100 --validation_epochs 5 --num_epochs 100 --base_net_lr 0.001 --batch_size 5
# 2020-12-05 05:13:14,571 - root - INFO - Use Cuda.
# 2020-12-05 05:13:14,571 - root - INFO - Namespace(balance_data=False, base_net=None, base_net_lr=0.001, batch_size=5, checkpoint_folder='models/', dataset_type='open_images', datasets=['data/open_images'], debug_steps=100, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb1-ssd', num_epochs=100, num_workers=4, pretrained_ssd='models/mobilenet-v1-ssd-mp-0_675.pth', resume=None, scheduler='cosine', t_max=100.0, use_cuda=True, validation_dataset=None, validation_epochs=5, weight_decay=0.0005)
# 2020-12-05 05:13:14,573 - root - INFO - Prepare training datasets.
# 2020-12-05 05:13:17,329 - root - INFO - Dataset Summary:Number of Images: 4414
# Minimum Number of Images for a Class: -1
# Label Distribution:
#         Traffic light: 7426
#         Traffic sign: 6112
# 2020-12-05 05:13:17,336 - root - INFO - Stored labels into file models/open-images-model-labels.txt.
# 2020-12-05 05:13:17,336 - root - INFO - Train dataset size: 4414
# 2020-12-05 05:13:17,336 - root - INFO - Prepare Validation datasets.
# 2020-12-05 05:13:17,397 - root - INFO - Dataset Summary:Number of Images: 95
# Minimum Number of Images for a Class: -1
# Label Distribution:
#         Traffic light: 131
#         Traffic sign: 72
# 2020-12-05 05:13:17,398 - root - INFO - validation dataset size: 95
# 2020-12-05 05:13:17,398 - root - INFO - Build network.
# 2020-12-05 05:13:17,461 - root - INFO - Init from pretrained ssd models/mobilenet-v1-ssd-mp-0_675.pth
# 2020-12-05 05:13:17,507 - root - INFO - Took 0.05 seconds to load the model.
# 2020-12-05 05:13:20,626 - root - INFO - Learning rate: 0.01, Base net learning rate: 0.001, Extra Layers learning rate: 0.01.
# 2020-12-05 05:13:20,626 - root - INFO - Uses CosineAnnealingLR scheduler.
# 2020-12-05 05:13:20,627 - root - INFO - Start training from epoch 0.
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /opt/conda/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 2020-12-05 05:13:43,310 - root - INFO - Epoch: 0, Step: 100, Average Loss: 8.4591, Average Regression Loss 4.5400, Average Classification Loss: 3.9191
# ...
# 2020-12-06 03:29:04,047 - root - INFO - Epoch: 99, Step: 800, Average Loss: 2.8470, Average Regression Loss 1.1756, Average Classification Loss: 1.6714
# 2020-12-06 03:29:19,321 - root - INFO - Trained 99.
# 2020-12-06 03:29:20,970 - root - INFO - Epoch: 99, Validation Loss: 2.8555, Validation Regression Loss 0.8317, Validation Classification Loss: 2.0238
# ```

# %%
model_after = 'models/mb1-ssd-Epoch-99-Loss-2.855540444976405.pth' # <-- update as needed!
if os.path.isfile(model_after):
    new_model_after = 'models/mb1-ssd-after.pth'
    shutil.copy(model_after,new_model_after)  # <-- renamed for clarity!
    print(f'\'{model_after}\' copied to \'{new_model_after}\'!')
model_after = new_model_after

# test model with open images dataset and choosen class labels
# UNCOMMENT TO RUN
# print(f'--> {model_after}')
# ! python pytorch-ssd/eval_ssd.py --dataset_type open_images \
#                                 --net mb1-ssd \
#                                 --dataset $root \
#                                 --trained_model $model_after \
#                                 --label_file $labels_txt
# Out:
# 'models/mb1-ssd-Epoch-99-Loss-2.855540444976405.pth' copied to 'models/mb1-ssd-after.pth'!

# %% [markdown]
# _Note: this is a snippet from the terminal console output..._
#
# ```
# 'models/mb1-ssd-Epoch-99-Loss-2.855540444976405.pth' copied to 'models/mb1-ssd-after.pth'!
# --> models/mb1-ssd-after.pth
# pytorch-ssd/eval_ssd.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
# It took 0.04280900955200195 seconds to load the model.
# process image 0
# Load Image: 0.011486 seconds.
# Inference time:  0.334181547164917
# Prediction: 0.390315 seconds.
#
# ...
#
#
# process image 94
# Load Image: 0.009266 seconds.
# Inference time:  0.004933595657348633
# Prediction: 0.031959 seconds.
#
#
# Average Precision Per-class:
# Traffic light: 0.4124242273993111
# Traffic sign: 0.4321535832282594
#
# Average Precision Across All Classes:0.42228890531378527
# ```

# %% [markdown]
# ### 1.3  Convert the Pytorch model to ONNX format and save it. {-}
# Per the reference below, some additional considerations are needed. First, the included `convert_to_caffe2_models.py` defines the model output_names as `scores` and `boxes`; however, ssd-mobilenetv1 appears to have outputs of `num_detections` (the number of detections), `detection_boxes` (a list of bounding boxes), `detection_scores` (the score for each detection), and `detection_classes` (an array of 10 integers).
#
# ref: https://github.com/onnx/models/tree/master/vision/object_detection_segmentation/ssd-mobilenetv1

# %%
model_after = 'models/mb1-ssd-Epoch-80-Loss-2.9748444682673405.pth'
print(f'Model exists: {os.path.isfile(model_after)}')
print(f'Labels exist: {os.path.isfile(labels_txt)}')

# some considerations are made since we are using mb1-ssd, which appears to have different outputs 
# than what are defined in the included 'convert'
# in the 

# convert the models to ONNX format
# os.environ["CUDA_VISIBLE_DEVICES"]=""
# Note: I modified convert_to_caffe2_models.py so that cuda could be used
! python pytorch-ssd/convert_to_caffe2_models.py mb1-ssd $model_after $labels_txt 
# WARNING: an unresolved error occurs (as shown below), but the ONNX file is still produced
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Model exists: True
# Labels exist: True
# WARNING: ONNX Optimizer has been moved to https://github.com/onnx/optimizer.
# All further enhancements and fixes to optimizers will be done in this new repo.
# The optimizer code in onnx/onnx repo will be removed in 1.9 release.
#
# Traceback (most recent call last):
#   File "pytorch-ssd/convert_to_caffe2_models.py", line 62, in <module>
#     init_net, predict_net = c2.onnx_graph_to_caffe2_net(model)
#   File "/opt/conda/lib/python3.7/site-packages/caffe2/python/onnx/backend.py", line 921, in onnx_graph_to_caffe2_net
#     return cls._onnx_model_to_caffe2_net(model, device=device, opset_version=opset_version, include_initializers=True)
#   File "/opt/conda/lib/python3.7/site-packages/caffe2/python/onnx/backend.py", line 876, in _onnx_model_to_caffe2_net
#     onnx_model = onnx.utils.polish_model(onnx_model)
#   File "/opt/conda/lib/python3.7/site-packages/onnx/utils.py", line 24, in polish_model
#     model = onnx.optimizer.optimize(model)
#   File "/opt/conda/lib/python3.7/site-packages/onnx/optimizer.py", line 55, in optimize
#     optimized_model_str = C.optimize(model_str, passes)
# IndexError: Input base_net.0.0.weight is undefined!

# %% [markdown]
#
# # (THERE IS A LATEX ERROR SOMEWHERE AFTER HERE)
# #### Answer:
# As shown above, we are receiving an error during conversion that the `base_net.0.0.weight` is undefined. After visualizing the model (below) we can see that this is an expected input to the network. Unless I have time to resolve this later, as of right now it is unclear why this input is undefined. Regardless of the error, it does appear that the ONNX file is still produced.

# %% [markdown]
# ### 1.4  Visualize the model using net drawer tool.
# * Compile the model using embed_docstring flag and show the visualization output.
# * Also show doc string (stack trace for PyTorch) for different types of nodes

# %%
# install python dependencies
# ! pip install graphviz pydot
# clone ONNX to access net_drawer.py
# ! git clone https://github.com/onnx/onnx.git
# Out:
# Collecting graphviz
#   Downloading graphviz-0.15-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pydot in /opt/conda/lib/python3.7/site-packages (1.4.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/conda/lib/python3.7/site-packages (from pydot) (2.4.7)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.15
# Cloning into 'onnx'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 25181 (delta 13), reused 14 (delta 0), pack-reused 25147
# Receiving objects: 100% (25181/25181), 18.63 MiB | 31.53 MiB/s, done.
# Resolving deltas: 100% (13591/13591), done.

# %%
# define netdrawer/visualization paths
input_onnx='models/mb1-ssd.onnx'
output_dot='data/onnx_output/mb1-ssd.dot'
output_svg='data/onnx_output/mb1-ssd.svg'
output_png='data/onnx_output/mb1-ssd.png'

# %%
# execute net_drawer
! python onnx/onnx/tools/net_drawer.py --input $input_onnx --output $output_dot --embed_docstring

# create visualization of the network
! dot -Tsvg $output_dot -o $output_svg
! dot -Tpng $output_dot -o $output_png
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.590833 to fit

# %%
# dsiplay the network using an Iframe to make it interactive
# display(SVG(filename=output_svg))
output_svg_name = os.path.basename(output_svg)

# Add a link to the  SVG
ipd.display(ipd.HTML("""A link to the SVG: <a href="{}">
                Open {} in new tab!</a><br/>""".format(output_svg,output_svg_name)))
# show the SVG in an IFrame
# ipd.display(ipd.HTML("""<H2>A scrollable IFrame showing the full network SVG:</H2>"""))
# ipd.display(ipd.HTML("""<iframe id="if" width="850" height="400" src={} frameborder="0"></iframe>""".format(svg_path)))

# display(IFrame(svg_path, height=400, width=850,onload="window.frames.scrollTo(1500,300)"))
# show a static image of the whole SVG
ipd.display(ipd.HTML("""<H4>A static image showing the complexity of the network:</H4></br>"""))
ipd.display(ipd.HTML(""" <a href="{}"><img src={} style="width:800px;  
                     alt="full network /></a></br><i>(Click to open)</i>""".format(output_png,output_png)))
# Out:
# A link to the SVG: <a href="data/onnx_output/mb1-ssd.svg">
#                 Open mb1-ssd.svg in new tab!</a><br/>
# <H4>A static image showing the complexity of the network:</H4></br>
#  <a href="data/onnx_output/mb1-ssd.png"><img src=data/onnx_output/mb1-ssd.png style="width:800px;
#                      alt="full network /></a></br><i>(Click to open)</i>

# %% [markdown]
# __Answer:__ As can be seen above, the network is quite complex. An attempt was made to show parts of the network in addition to the entire network. The embedded doc_strings appear to be enabled (as shown below), but none of the ops nodes seemed to have any useful information.
#
# <!-- <img src="q1_showing-docstring-empty.PNG"
#      style="width:700px;  border: 5px solid black;"
#      alt="Showing Empty Doc-String" />    -->
#
#
# After exploring the network graphic, it can be seen that the expected input (for later) is "input".
# <!-- <div style="float: left; padding: 10px;">
#   <img src="q1_input-input.PNG"
#      style="height:180px;  border: 5px solid black;"
#      alt="scores output" />
# </div> -->
#
# After exploring the network graphic, it can be seen that the expected outputs (for later) are "scores" and "boxes".
# <!-- <div class="row">
#   <div style="float: left; width: 33.33%;padding: 10px;">
#     <img src="q1_output-boxes.PNG"
#      style="height:200px;  border: 5px solid black;"
#      alt="boxes output" />
#   </div>
#   <div style="float: left; width: 33.33%;padding: 10px;">
#     <img src="q1_output-scores.PNG"
#      style="height:200px;  border: 5px solid black;"
#      alt="scores output" />
#   </div>
# </div> -->

# %%
tmp_img = Image.open('q1_showing-docstring-empty.PNG')
plt.figure(figsize=(12,12))
plt.imshow(tmp_img)
plt.title(f'Showing doc-strings are embedded, but empty.')
plt.axis('off')
plt.show()

ipd.display(ipd.Image('q1_showing-docstring-empty.PNG'))

# %%
# # helper function to dynamically generate the GCP host url
# def getGcpUrl(project,zone,show_url=True):
#     ''' GCP project and zone are required '''
#     import googleapiclient.discovery
#     compute = googleapiclient.discovery.build('compute', 'v1')
#     instance = compute.instances().list(project=project,zone=zone).execute()
#     # parse the compute data
#     items = instance['items'][0]
#     name = items['name']
#     metadata = items['metadata']
#     # get the url
#     url = next((item['value'] for item in metadata['items'] if item["key"] == "proxy-url"),None)
#     if url and show_url:
#         display(HTML("""<a href="{} target="_blank"">Notebook link: {}</a><br/><br/>""".format(url,name)))
#     return url,name

# instance_url,instance_name = getGcpUrl(project='e6998-dl',zone='us-west1-a',show_url=False)
# notebook_name = 'comse6998-hw5'
# notebook_path = f'{instance_url}/files/{notebook_name}/'
# extra = '?_xsrf=2%7C59e4a71c%7Cda98d08383b0e729cc47f122b5d9f600%7C1605335552'
# # svg_path = f'{notebook_path}/{output_svg}/{extra}'
# svg_path = os.path.join(os.path.join(notebook_path,output_svg),extra)

# display(HTML("""<a href="{} target="_blank"">Open {} in new tab!</a><br/><br/>""".format(svg_path,output_svg_name)))
# # display(HTML("""<iframe src="{}" frameborder="0" width="800" height="200"></iframe>""".format(svg_path)))

# %% [markdown]
# ### 1.5 Deploy the ONNX model on ONNX runtime (ORT) server. {-}
# * Set up the environment following steps listed in the tutorial.
# * Then make HTTP request to the ORT server.
# * Test the inferencing set-up using 1 image from each of the two selected categories.

# %%
import assets.onnx_ml_pb2 as onnx_ml_pb2
import assets.predict_pb2 as predict_pb2

# %%
# from the ONNX inferencing tutorial refrenced above
# download the ONNXRuntmie Server image
# ! sudo docker pull mcr.microsoft.com/onnxruntime/server
# Out:
# Using default tag: latest
# latest: Pulling from onnxruntime/server
#
# 8f4ce990: Pulling fs layer
# 282d9c4b: Pulling fs layer
# 3db6dc03: Pulling fs layer
# c605f3f1: Pulling fs layer
# fba003ea: Pulling fs layer
# 34ff9c7d: Pulling fs layer
# e5c2fefd: Pulling fs layer
# Digest: sha256:a23da0977bbc4aca4d3de56ad648ebde86031e61d7a3b7cbe1daaebbc7f6ad3d[8A
# Status: Downloaded newer image for mcr.microsoft.com/onnxruntime/server:latest
# mcr.microsoft.com/onnxruntime/server:latest

# %%
PORT_NUMBER = 9001
# start the docker container
! echo 'Loading model {input_onnx}'
! echo
# ! sudo docker run -it -v $(pwd):$(pwd) -p $PORT_NUMBER:8001 mcr.microsoft.com/onnxruntime/server --model_path $(pwd)/$input_onnx
# ! docker stop 6469b5de2391                                                
! docker ps
# Out:
# Loading model models/mb1-ssd.onnx
#
# CONTAINER ID        IMAGE                          COMMAND                  CREATED             STATUS              PORTS               NAMES
# 777fcc9aa46e        gcr.io/inverting-proxy/agent   "/bin/sh -c '/opt/bi…"   4 hours ago         Up 4 hours                              proxy-agent

# %%
# visualize the data and choose some decent pictures (or skip and do it at random)
# import glob
# image_path = f'{root}/test'

# image_list = []
# for filename in glob.glob(f'{image_path}/*.jpg'):
#     im=Image.open(filename)
#     image_list.append(im)
    
# dim1 = int(np.ceil(np.sqrt(len(image_list))))
# dim2 = int(np.floor(np.sqrt(len(image_list))))

# print(dim1*dim2)
# print(len(image_list))
# # display samles
# # title = 'Samples of \'{}\' Dataset'.format(data_name)
# fig = plt.figure(figsize=(24,50))
# # fig.suptitle(title, fontsize=16)
# for i in range(0,dim1):
#     for j in range(0,dim2):
#         idx =i*dim2+j
# #         print(idx)
#         axn = fig.add_subplot(dim1, dim2, idx+1)
#         axn.axis('off')
#         if(idx < len(image_list)):
#             fname = os.path.split(image_list[idx].filename)[-1].split('.')[0]
#             axn.set_title(fname)
#             axn.imshow(image_list[idx])
# plt.tight_layout(pad=1.0)
# plt.show()

# %%
root = 'data/open_images_beer'
test_images = 'data/open_images_beer/test'
# path to test images
# image_path = ''#'data/trainval/open_images/test'
# load the label and test annotation metadata
class_desc = pd.read_csv(f'{root}/class-descriptions-boxable.csv',names=['LabelName','Category'])
test_ann = pd.read_csv(f'{root}/test-annotations-bbox.csv')
test_ann = test_ann[['ImageID','LabelName']]

# get the labels based on the categories
cat1_label = class_desc.loc[class_desc['Category'] == cat1, 'LabelName'].item()
cat2_label = class_desc.loc[class_desc['Category'] == cat2, 'LabelName'].item()


# get the image names based on the label names
cat1_images = list(test_ann.loc[test_ann['LabelName'] == cat1_label, 'ImageID'])
cat2_images = list(test_ann.loc[test_ann['LabelName'] == cat2_label, 'ImageID'])
# uncomment to chose specific images (from above)
# cat1_images = ['bf9c1ddbe87e34a0']
# cat2_images = ['6b79e1664522ca64']

# randomly select one image from each category and open it
np.random.seed(698)
# image from 1st category
img1_name = np.random.choice(cat1_images,1)[0]
cat1_image = f'{test_images}/{img1_name}.jpg'
img1 = Image.open(cat1_image)
# image from 2nd category
img2_name = np.random.choice(cat2_images,1)[0]
cat2_image = f'{test_images}/{img2_name}.jpg'
img2 = Image.open(cat2_image)
# we need to resize each of the images to meet the requirements
# of the SSD model.
img1 = img1.resize((300, 300), Image.BILINEAR)
img2 = img2.resize((300, 300), Image.BILINEAR)

# show the image of each category
plt.figure(figsize=(12,9))
plt.imshow(img1)

plt.title(f'{cat1} - {img1_name}.jpg')
plt.axis('off')
plt.show()
plt.figure(figsize=(12,9))
plt.imshow(img2)
plt.title(f'{cat2} - {img2_name}.jpg')
plt.axis('off')
plt.show()

# %%
# Preprocess and normalize the image (same as the tutorial)
img_data = np.array(img1)
img_data = np.transpose(img_data, [2, 0, 1])
img_data = np.expand_dims(img_data, 0)
mean_vec = np.array([0.485, 0.456, 0.406])
stddev_vec = np.array([0.229, 0.224, 0.225])
norm_img_data = np.zeros(img_data.shape).astype('float32')
for i in range(img_data.shape[1]):
    norm_img_data[:,i,:,:] = (img_data[:,i,:,:]/255 - mean_vec[i]) / stddev_vec[i]

# per https://github.com/onnx/models/tree/master/vision/object_detection_segmentation/ssd-mobilenetv1
# img_data = np.array(img1.getdata()).reshape(3, img1.size[0],img1.size[1])
# # img_data = np.expand_dims(img_data.astype(np.uint8), axis=0)
# img_data = np.expand_dims(img_data.astype(np.float32), axis=0)

# %%
# Create request message to be sent to the ORT server (same as tutorial)
input_tensor = onnx_ml_pb2.TensorProto()
input_tensor.dims.extend(norm_img_data.shape)
# input_tensor.dims.extend(img_data.shape)
input_tensor.data_type = 1
input_tensor.raw_data = norm_img_data.tobytes()
# input_tensor.raw_data = img_data.tobytes()
# prediction requyest
request_message = predict_pb2.PredictRequest()
# For your model, the inputs name should be something else customized by yourself. Use Netron to find out the input name.
# request_message.inputs["image"].data_type = input_tensor.data_type
# request_message.inputs["image"].dims.extend(input_tensor.dims)
# request_message.inputs["image"].raw_data = input_tensor.raw_data
# nc2677: from above, we discovered that the input is actually 'input'
request_message.inputs["input.1"].data_type = input_tensor.data_type
request_message.inputs["input.1"].dims.extend(input_tensor.dims)
request_message.inputs["input.1"].raw_data = input_tensor.raw_data
# content header list
content_type_headers = ['application/x-protobuf', 'application/octet-stream', 'application/vnd.google.protobuf']
for h in content_type_headers:
    request_headers = {
        'Content-Type': h,
        'Accept': 'application/x-protobuf'
    }

# %%
model_name = os.path.basename(input_onnx).split('.')[0]
print(f'Using model: {model_name}')
print('Note: the model name doesn\'t matter, they support only one model...')
# Inference run using ORT server (update port number according to the docker settings above)
# PORT_NUMBER = 9001 #nc2677: set above
inference_url = f"http://127.0.0.1:{PORT_NUMBER}/v1/models/default/versions/1:predict"
response = requests.post(inference_url, headers=request_headers, data=request_message.SerializeToString())
# print(response.content)
# Out:
# Using model: mb1-ssd
# Note: the model name doesn't matter, they support only one model...

# %% [markdown]
# __Answer:__ the ONNX runtime server was successfully created in this problem and the inferencing process was completed using the tutorial for each step. I've displayed the two images above and went through each of the tutorial steps to make sure the image was put in the proper format for inferencing. Now it is time to parse the response from the ORT server.

# %% [markdown]
# ### 1.6 Parse the response message from the ORT server and annotate the two images. {-}
# * Show inferencing output (bounding boxes with labels) for the two images.

# %%
#Parse response message (same as tutorial)
response_message = predict_pb2.PredictResponse()
response_message.ParseFromString(response.content)

# For your model, the outputs names should be something else customized by yourself. Use Netron to find out the outputs names.
# bboxes = np.frombuffer(response_message.outputs['bboxes'].raw_data, dtype=np.float32)
# labels = np.frombuffer(response_message.outputs['labels'].raw_data, dtype=np.int64)
# scores = np.frombuffer(response_message.outputs['scores'].raw_data, dtype=np.float32)
# nc2677: from above, we discovered that the outpus are 'boxes' and 'scores'
# detections = np.frombuffer(response_message.outputs['detections'].raw_data, dtype=np.float32)
bboxes = np.frombuffer(response_message.outputs['boxes'].raw_data, dtype=np.float32)
# labels = np.frombuffer(response_message.outputs['labels'].raw_data, dtype=np.int64)
# added per Piazza @374
scores = np.frombuffer(response_message.outputs['scores'].raw_data, dtype=np.float32)
labels = np.argmax(scores.reshape((3000, 3)), axis=1)

# print('Detections shape:', response_message.outputs['detections'].dims)
print('Boxes shape:', response_message.outputs['boxes'].dims)
print('Labels shape:', labels.shape)
print('Scores shape:', response_message.outputs['scores'].dims)
# Out:
# Boxes shape: [1, 3000, 4]
# Labels shape: (3000,)
# Scores shape: [1, 3000, 3]

# %%
np.unique(labels)
# Out:
# array([0, 1])

# %%
# not_background = labels[labels>0]
# print(not_background)

# scores_new = scores.reshape((3000, 3))
# bboxes_new = bboxes.reshape((3000, 4))

# for i in range(0,len(scores_new)-1,100):
#     print(f'boxes: {bboxes_new[i]}')
#     print(f'scores: {scores_new[i]}')
#     print(f'label: {labels[i]}')
#     print()


# print(scores_new.shape)

# %%
# Parse the list of class labels
# classes = [line.rstrip('\n') for line in open('assets/coco_classes.txt')]
classes = [line.rstrip('\n') for line in open('models/open-images-model-labels.txt')]

# Plot the bounding boxes on the image
plt.figure()
fig, ax = plt.subplots(1, figsize=(12,9))
ax.imshow(img1)

resized_width = 300  # we resized the original image, remember ? 
resized_height = 300
num_boxes = 6 # we limit displaying to just 6 boxes to avoid clogging the result image with boxes
               # The results are already sorted based on box confidences, so we just pick top N boxes without sorting
    
for c,label in enumerate(labels):    
    # skip 'BACKGROUND'
    if (label == 0):
        continue
    # draw the bounding boxes
    base_index = c * 4
    y1, x1, y2, x2 = bboxes[base_index] * resized_height, \
                     bboxes[base_index + 1] * resized_width, \
                     bboxes[base_index + 2] * resized_height, \
                     bboxes[base_index + 3] * resized_width 
    color = 'blue'
    box_h = (y2 - y1)
    box_w = (x2 - x1)
    bbox = patches.Rectangle((y1, x1), box_h, box_w, linewidth=2, edgecolor=color, facecolor='none')
    ax.add_patch(bbox)
    text = f'{classes[label]} ({scores[c]:0.3f})'
    plt.text(y1, x1, s=text, color='white', verticalalignment='top', bbox={'color': color, 'pad': 0})

plt.axis('off')

# Save image
plt.savefig("data/results/mb1-ssd_result.jpg", bbox_inches='tight', pad_inches=0.0)
plt.show()

# %%
print(len(bboxes))
print(bboxes)

print(len(labels))
print(labels)
# Out:
# 12000
# [-0.0193277  -0.01386145  0.08365506 ... -0.010732    1.00804
#   0.98393124]
# 9000
# [9.8623997e-01 4.0159109e-03 9.7441385e-03 ... 1.7200716e-02 8.1970188e-04
#  9.8197961e-01]

# %%
print(classes)
# Out:
# ['BACKGROUND', 'Traffic light', 'Traffic sign']

# %% [markdown]
# ## Problem 2 - ML Cloud Platforms (20) {-}
# In this question you will analyze different ML cloud platforms and compare their service offerings. In
# particular, you will consider ML cloud offerings from IBM, Google, Microsoft, and Amazon and compare
# them on the basis of following criteria:

# %% [markdown]
# ### 2.1 Frameworks {-}
# DL framework(s) supported and their version. (_Here we are referring to machine learning platforms which have their own inbuilt images for different frameworks_)
#
#
# **Note 1: the information below assumes the most recent `platform` release as some frameworks may have been supported in previous `platform` versions but are no longer supported.**
# **Note 2: given the extent of this question, focus was on natively supported frameworks (i.e., frameworks that are listed in a support document) vs. frameworks that "can" be configured (i.e., frameworks that are documented on a blog).**
#
#
#
# |Platform|TensorFlow|TensorFlow2|PyTorch|MXNet|Chainer| CNTK| Keras | Caffe| Caffe2| Theano| XGBoost | R | Scikit-learn | Spark |
# |--------|:--------:|:-----:|:-----:|:-----:|:---:|:-----:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |[Amazon](https://docs.aws.amazon.com/dlami/latest/devguide/features.html "AWS DL") | X | X | X | X | X | | X |||||X| X | X |
# |[Google](https://cloud.google.com/ai-platform/deep-learning-vm/docs/images?hl=en_US#listing-versions "GCP DL") | 1.8+ | 2.0+ | 0.4+ | 1.3+ | 4.3+ | 2.7+ | X |X|||0.8+|3.5+| X | X |
# |[IBM](https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/pm_service_supported_frameworks.html "IBM DL") | 1.15 | 2.1 | 1.2 | | | | 2.2.5 |X|X||0.8+|| 0.19+ | 2.4 |
# |[Microsoft](https://docs.microsoft.com/en-us/azure/machine-learning/data-science-virtual-machine/dsvm-tools-deep-learning-frameworks "MS Azure DL") | 1.13 | X | 1.2 | 1.3 | 5.2 | 2.5.1 |  2.2.4 |X|X|1.0.3|X|| X | X|

# %% [markdown]
# ### 2.2 Compute units {-}
# The type(s) of compute units offered, i.e., GPU types.
#
# * Amazon [Ref.](https://aws.amazon.com/nvidia/)
#    * EC2 P4d instances feature NVIDIA Tesla `A100` GPUs
#    * EC2 P3 instances feature NVIDIA Tesla `V100` GPUs
#    * EC2 G4 instances feature NVIDIA Tesla `T4` GPUs
# * Google: [Ref.](https://cloud.google.com/compute/docs/gpus)
#    * Features NVIDIA Tesla `T4`, `V100`, `P100`, `P4`, and `K80` GPUs (availability depends on compute zone)
# * IBM: [Ref.](https://www.ibm.com/nl-en/cloud/gpu)
#    * Features NVIDIA Tesla `M60`, `K80`, `P100` an `V100` GPUs.
# * Microsoft Azure: [Ref.](https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-gpu)
#    * NC T4_v3-series features NVIDIA Tesla `T4` GPU and AMD `EPYC2 Rome` CPU
#    * NCv3-series features NVIDIA Tesla `V100` GPU
#    * NDv2-series features the Nvidia Volta `V100` GPU and Intel `Xeon Platinum 8168` CPU
#    * NV- and NVv3-series feature NVIDIA Tesla `M60` GPU
#    * NVv4-series feature AMD Radeon Instinct `MI25` GPU

# %% [markdown]
# ### 2.3 Model lifecycle management {-}
# Tools supported to manage ML model lifecycle.
#
# * Amazon: [SageMaker Studio](https://aws.amazon.com/sagemaker/?utm_source=thenewstack&utm_medium=website&utm_campaign=platform#How_it_works) is the "first integrated development environment" that supports the full lifecycle of a ML model. From pre-processing, to training and tuning, through deployment and management.
# * Google: GCP has [AI Platform Noteboks](https://cloud.google.com/ai-platform/notebooks/docs) to support early development and training of models.

# %% [markdown]
# ### 2.4 Monitoring {-}
# availability of application logs and resource (GPU, CPU, memory) usage monitoring data to the user.

# %% [markdown]
# ### 2.5 Visualization during training {-}
# performance metrics like accuracy and throughput.

# %% [markdown]
# ### 2.6 Elastic Scaling {-}
# support for elastic scaling compute resources of an ongoing job.

# %% [markdown]
# ### 2.7 Training job description {-}
# Training job description file format. Show how the same training job is specified in different ML platforms. Identify similar fields in the training job file for the 4 ML platforms through an example.

# %%
! gcloud compute images list \
        --project deeplearning-platform-release \
        --no-standard-images
